# %%
Рекомендованные ресурсы по ML и работе с данными от автора курса Анастасия Лобкина



Библиотеки

***
Визуализация

библиотека matplotlib, как основа большинства инструментов визуализации на python
seaborn

***
Анализ и обработка данных

pandas - про таблицы и хранение данных
scipy - еще больше реализованных функций для решения задач с данными

***
Онлайн-ресурсы
Из бесплатных онлайн-ресурсов могу порекомендовать следующие:

Хендбук по машинному обучению от Яндекса 
Курс по машинному обучению от Сбербанка и Академии искусственного интеллекта. 
Здесь можно пройти весь путь от полного незнания python до основ машинного обучения. 
Курс последовательно научит вас работе таблицами (pandas), визуализации данных (matplotlib, plotly, seaborn) 
и построению моделей машинного обучения (sklearn) Несмотря на то, что ресурс разработан для подготовки школьников 
к Олимпиаде НТИ, он подойдет всем начинающим в Data Science, материал здесь подается легко и интересно

***
Книги
Data Science. Наука о данных с нуля | Джоэл Грас - замечательная книга, автор простым языком объяснет 
основные алгоритмы науки о данных. Читать можно действительно с нуля
Искусство статистики. Как находить ответы в данных | Дэвид Шпигельхалтер - как на основе данных сделать 
правильные выводы (ну или не сделать неправильные)


***
Телеграм каналы
Для погружения в новую область бывает полезно окружить себя новостями и людьми из новой сферы. 
Следующие телеграм-каналы могут в этом помочь:

AltFuture 
настенька и графики - канал Насти Кузнецовой о визуализации данных (не только на python)
Борис опять - автор пишет про работу в ML и интересные статьи из области. Летом/осенью 2022 
года была очень познавательная серия постов про поиск работы, резюме и собеседования. Сейчас 
Борис ведет #лабораторный_журнал о работе DS в области компьютерного зрения в Португалии
New Yorko Times - канал Юрия Кашницкого, создателя курса https://mlcourse.ai/book/index.html 
    и Principal Machine Learning Scientist в научном издательстве Elsevier
